# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb
pd.set_option('display.max_columns',30)
import numpy as np

# %%
df = pd.read_csv('/Users/utkarshsingh/Downloads/Warehouse Report.csv',header = 1)

# %%
df.head(5)
# Out:
#                ITEM ID LIST OF ITEMS           SKU  \
# 0  4051872000000512232     Product 1  7.388505e+11
# 1  4051872000000242010     Product 2  3.846754e+11
# 2  4051872000002001964     Product 3  8.591984e+11
# 3  4051872000000383602     Product 4  5.097334e+11
# 4  4051872000003592104     Product 5  5.255261e+11
#
#   \n          Warehouse Name\n             Item Type Purchase Invoice Channel  \
# 0                    TX Boyz Wholesale     Cosmetics                  Offline
# 1              Tx Boyz Wholesale A#103     Cosmetics                  Offline
# 2                   TEXAS DISTRIBUTION    Novelities                   Online
# 3             TX Boyz WHOLESALE-khaled     Cosmetics                  Offline
# 4                    TX Boyz Wholesale  ExoticDrinks                  Offline
#
#   Order Priority  Order Date  Order ID  Qty Ordered  Qty in  Qty out  \
# 0     LOW/MEDIUM  2023-03-02  15157614       128868  106780    66204
# 1     LOW/MEDIUM  2019-02-13  57105109       145707  120733    74854
# 2  MOST PRIORITY  2023-08-14  15319448       136952  113478    70357
# 3            LOW  2016-11-02  43709238       123910  102672    63656
# 4         MEDIUM  2019-01-13  64467696       132856  110084    68252
#
#    Stock On Hand  Committed Stock  Available for sale  status unit  \
# 0          40576             4332               36244  active  pcs
# 1          45878            34596               11282  active  pcs
# 2          43122             1000               42122  active  PCS
# 3          39015             9096               29919  active  PCS
# 4          41832             5661               36171  active  PCS
#
#    Selling Price  Cost Price created_by  Total money on hold  \
# 0           3.57        2.75        xyz                36955
# 1           8.45        6.50        xyz                56510
# 2          17.00       13.75        xyz                32057
# 3           8.45        6.50        xyz                39284
# 4           3.00        2.25        xyz                28408
#
#    Item Availability rating  OFFLINE rating  Online booking Rating  \
# 0                       4.0               2                      3
# 1                       2.0               2                      3
# 2                       0.0               2                      2
# 3                       4.0               3                      1
# 4                       3.0               4                      2
#
#    Packaging Rating  Delivery Rating
# 0                 3              0.0
# 1                 4              4.0
# 2                 3              NaN
# 3                 1              0.0
# 4                 2              0.0

# %% [markdown]
# ## Statistics

# %%
df.drop_duplicates(inplace=True)
df.describe()
# Out:
#             ITEM ID           SKU      Order ID    Qty Ordered         Qty in  \
# count  2.817900e+04  2.815600e+04  2.817900e+04   28179.000000   28179.000000
# mean   4.051872e+18  5.491682e+11  5.516339e+07  134988.125696  111851.068633
# std    3.310302e+08  2.606304e+11  2.601632e+07    8663.006096    7178.160407
# min    4.051872e+18  1.000024e+11  1.000045e+07  120002.000000   99434.000000
# 25%    4.051872e+18  3.228462e+11  3.255862e+07  127456.000000  105610.000000
# 50%    4.051872e+18  5.495509e+11  5.554572e+07  134989.000000  111852.000000
# 75%    4.051872e+18  7.734898e+11  7.785211e+07  142476.000000  118055.500000
# max    4.051872e+18  9.999561e+11  9.999901e+07  149999.000000  124289.000000
#
#             Qty out  Stock On Hand  Committed Stock  Available for sale  \
# count  28179.000000   28179.000000     28179.000000        28179.000000
# mean   69347.661556   42503.406579      9044.607474        33458.799106
# std     4450.457240    2727.699111     14040.331362        14319.415985
# min    61649.000000   37785.000000      1000.000000       -53144.000000
# 25%    65478.000000   40132.000000      1000.000000        30590.500000
# 50%    69348.000000   42504.000000      1000.000000        38680.000000
# 75%    73194.500000   44861.000000     11690.000000        42209.500000
# max    77059.000000   47230.000000     93295.000000        46230.000000
#
#        Selling Price    Cost Price  Total money on hold  \
# count   28179.000000  28179.000000         2.817900e+04
# mean      193.387409     95.442977         3.812247e+06
# std       141.303082     91.233916         4.045959e+06
# min         0.000000      0.000000         0.000000e+00
# 25%        61.450000     13.000000         6.489350e+04
# 50%       179.760000     60.130000         2.193042e+06
# 75%       317.690000    168.170000         7.112802e+06
# max       935.000000    660.000000         2.650138e+07
#
#        Item Availability rating  OFFLINE rating  Online booking Rating  \
# count              28172.000000    28179.000000           28179.000000
# mean                   2.995882        3.506476               3.491927
# std                    1.487104        1.355786               1.295489
# min                    0.000000        1.000000               1.000000
# 25%                    2.000000        2.000000               3.000000
# 50%                    3.000000        4.000000               4.000000
# 75%                    4.000000        5.000000               5.000000
# max                    5.000000        5.000000               5.000000
#
#        Packaging Rating  Delivery Rating
# count      28179.000000     23941.000000
# mean           3.549487         3.496846
# std            1.221622         1.294404
# min            1.000000         0.000000
# 25%            3.000000         3.000000
# 50%            4.000000         4.000000
# 75%            4.000000         5.000000
# max            5.000000         5.000000

# %%
ax = sb.countplot(x='Item Type', data=df, order = df['Item Type'].value_counts(ascending=False).index)
abs_values = df['Item Type'].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=abs_values)
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/utkarshsingh/PycharmProjects/DSA/venv/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/utkarshsingh/PycharmProjects/DSA/venv/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df['Order_Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Order Year'] = df['Order_Date'].dt.year

# %%
Yearwise_df =  pd.pivot_table(data=df , index = 'Order Year' , columns ='Order Priority' ,values = 'Order ID' , aggfunc='count')

# %%
Yearwise_df
# Out:
# Order Priority   HIGH    LOW  LOW/MEDIUM  MEDIUM  MOST PRIORITY
# Order Year
# 2015            712.0  676.0         NaN   669.0          665.0
# 2016            765.0  719.0         NaN   721.0          702.0
# 2017            689.0  700.0         NaN   699.0          690.0
# 2018            699.0  740.0         NaN   710.0          716.0
# 2019            716.0  714.0         1.0   667.0          706.0
# 2020            700.0  713.0         NaN   688.0          743.0
# 2021            702.0  736.0         NaN   707.0          698.0
# 2022            696.0  695.0         NaN   709.0          713.0
# 2023            670.0  756.0         1.0   705.0          716.0
# 2024            711.0  685.0         NaN   678.0          681.0

# %%
Yearwise_df_1 =  pd.pivot_table(data=df , index = 'Order Year' , columns ='Item Type' ,values = 'Qty Ordered' , aggfunc='sum')

# %%
Yearwise_df_1
# Out:
# Item Type   Chocolates/Biscuits     Clothes   Cosmetics  Exotic Chips  \
# Order Year
# 2015                 29771977.0  29014365.0  65130484.0    32288018.0
# 2016                 32137367.0  35581307.0  68587817.0    36819163.0
# 2017                 29748103.0  32113089.0  62690259.0    32960795.0
# 2018                 30378958.0  29953504.0  69277665.0    30594858.0
# 2019                 31752112.0  32111272.0  62813294.0    31775973.0
# 2020                 32774540.0  32519246.0  61395273.0    34196007.0
# 2021                 35359444.0  30937672.0  68223331.0    32982256.0
# 2022                 33650537.0  31568395.0  59037988.0    31397379.0
# 2023                 32149442.0  32600762.0  65247251.0    35258791.0
# 2024                 33353050.0  31708532.0  62434581.0    29070381.0
#
# Item Type   ExoticDrinks  Glass Items  Incense sticks  Novelities  \
# Order Year
# 2015          58275314.0   61257246.0      61988809.0         NaN
# 2016          61674978.0   62597746.0      61026347.0         NaN
# 2017          63993063.0   61334578.0      59462401.0         NaN
# 2018          60176122.0   64207882.0      66262002.0         NaN
# 2019          63077015.0   65691921.0      60448984.0         NaN
# 2020          64951955.0   62588326.0      64828033.0         NaN
# 2021          63468434.0   56905889.0      60687196.0         NaN
# 2022          63291503.0   61625613.0      67453333.0         NaN
# 2023          67198084.0   56612675.0      61683930.0    136952.0
# 2024          61178406.0   61885272.0      58913756.0         NaN
#
# Item Type   Office Supplies
# Order Year
# 2015             29960477.0
# 2016             34145122.0
# 2017             32790225.0
# 2018             35277561.0
# 2019             31238372.0
# 2020             30285154.0
# 2021             35219260.0
# 2022             31971265.0
# 2023             33198677.0
# 2024             33495278.0

# %%
Yearwise_df_1.plot.line()
# Out:
# <Axes: xlabel='Order Year'>

# %%
x =pd.pivot_table(data=df,index='Item Type' , values = ['Qty Ordered','Qty in'] , aggfunc=np.sum)
# Out:
# /var/folders/p2/0dct3c2n3031b7sgthqw_np00000gn/T/ipykernel_54313/3843505653.py:1: FutureWarning: The provided callable <function sum at 0x107eed700> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   x =pd.pivot_table(data=df,index='Item Type' , values = ['Qty Ordered','Qty in'] , aggfunc=np.sum)

# %%
x
# Out:
#                      Qty Ordered     Qty in
# Item Type
# Chocolates/Biscuits    321075530  266042969
# Clothes                318108144  263584175
# Cosmetics              644837943  534312278
# Exotic Chips           327343621  271236704
# ExoticDrinks           627284874  519767821
# Glass Items            614707148  509345922
# Incense sticks         622754791  516014207
# Novelities                136952     113478
# Office Supplies        327581391  271433709

# %%
x.plot.bar()
plt.show()

# %%
df['Profit %']  = (df['Selling Price']-df['Cost Price'])/df['Cost Price']

# %%
profitmargin = pd.pivot_table(data=df , index= 'Order Year' , columns='Item Type' , values ='Profit %' , aggfunc='mean')

# %%
profitmargin
# Out:
# Item Type   Chocolates/Biscuits    Clothes  Cosmetics  Exotic Chips  \
# Order Year
# 2015                   5.539937   5.575766   6.428788      4.166167
# 2016                   6.523248   6.160604   5.505704      9.053539
# 2017                   6.754144   4.240078   7.575578      5.328179
# 2018                   6.988597   5.474024   4.874900      5.015777
# 2019                   4.782575   7.475308   7.984348      7.959434
# 2020                   6.713227   8.490453  10.895663      9.850569
# 2021                   5.353256  30.063189   8.379610      8.972164
# 2022                   7.066624   5.381739   7.230758      5.651768
# 2023                   5.820349   5.998738   5.914504      4.663290
# 2024                   7.718502   4.847334   5.377813      5.398960
#
# Item Type   ExoticDrinks  Glass Items  Incense sticks  Novelities  \
# Order Year
# 2015            6.008516     7.291281       11.335618         NaN
# 2016            5.423189     5.069736        6.598635         NaN
# 2017            6.898602     6.073508        8.376088         NaN
# 2018            7.766116     3.478458        6.862289         NaN
# 2019            6.523837     6.561197        7.336759         NaN
# 2020            5.498321     5.410133        5.383544         NaN
# 2021           14.248471     7.499043        6.953110         NaN
# 2022            6.803586     6.980632        6.361532         NaN
# 2023            5.761381    24.224278        7.770798    0.236364
# 2024            6.227440     6.384537        6.385342         NaN
#
# Item Type   Office Supplies
# Order Year
# 2015               6.232022
# 2016               7.099502
# 2017               4.167332
# 2018               8.797669
# 2019               3.814456
# 2020               6.517857
# 2021               5.354607
# 2022               9.515966
# 2023               5.418570
# 2024               7.063647

# %%
profitmargin.plot.line()
plt.show()

# %%
df.columns
# Out:
# Index(['ITEM ID', 'LIST OF ITEMS', 'SKU',
#        '\n          Warehouse Name\n        ', 'Item Type',
#        'Purchase Invoice Channel', 'Order Priority', 'Order Date', 'Order ID',
#        'Qty Ordered', 'Qty in', 'Qty out', 'Stock On Hand', 'Committed Stock',
#        'Available for sale', 'status', 'unit', 'Selling Price', 'Cost Price',
#        'created_by', 'Total money on hold', 'Item Availability rating',
#        'OFFLINE rating', 'Online booking Rating', 'Packaging Rating',
#        'Delivery Rating', 'Order_Date', 'Order Year', 'Profit %'],
#       dtype='object')

# %%
StockINandCommited = pd.pivot_table(data=df , index = 'Order Date' , columns ='Item Type' , values = ['Stock On Hand','Committed Stock'], aggfunc='sum')

# %%
StockINandCommited
# Out:
#                Committed Stock                                               \
# Item Type  Chocolates/Biscuits  Clothes Cosmetics Exotic Chips ExoticDrinks
# Order Date
# 2015-01-01             35537.0      NaN       NaN          NaN      15498.0
# 2015-01-02                 NaN  35793.0   12440.0          NaN      18770.0
# 2015-01-03              1876.0      NaN    2262.0      25012.0      23858.0
# 2015-01-04                 NaN      NaN       NaN       1000.0          NaN
# 2015-01-05                 NaN   1000.0    6270.0       9660.0          NaN
# ...                        ...      ...       ...          ...          ...
# 2024-12-26             56961.0      NaN       NaN          NaN       1000.0
# 2024-12-27             10781.0      NaN   12241.0          NaN       2295.0
# 2024-12-28                 NaN   2000.0       NaN          NaN          NaN
# 2024-12-29                 NaN   1251.0   30917.0       2143.0      63413.0
# 2024-12-30                 NaN      NaN       NaN       2665.0          NaN
#
#                                                                   \
# Item Type  Glass Items Incense sticks Novelities Office Supplies
# Order Date
# 2015-01-01         NaN         1000.0        NaN          1000.0
# 2015-01-02     39883.0         1000.0        NaN             NaN
# 2015-01-03      2999.0        38998.0        NaN          1054.0
# 2015-01-04         NaN            NaN        NaN          1740.0
# 2015-01-05     24299.0        74122.0        NaN          1643.0
# ...                ...            ...        ...             ...
# 2024-12-26      1000.0        25216.0        NaN          1000.0
# 2024-12-27      1000.0        47333.0        NaN          1000.0
# 2024-12-28         NaN            NaN        NaN             NaN
# 2024-12-29      1000.0         1313.0        NaN             NaN
# 2024-12-30      6547.0        42673.0        NaN             NaN
#
#                  Stock On Hand                                               \
# Item Type  Chocolates/Biscuits  Clothes Cosmetics Exotic Chips ExoticDrinks
# Order Date
# 2015-01-01             41488.0      NaN       NaN          NaN      87060.0
# 2015-01-02                 NaN  40327.0   84444.0          NaN      39453.0
# 2015-01-03             46331.0      NaN   40354.0      41993.0      38632.0
# 2015-01-04                 NaN      NaN       NaN      39918.0          NaN
# 2015-01-05                 NaN  39963.0   37872.0     128544.0          NaN
# ...                        ...      ...       ...          ...          ...
# 2024-12-26             78826.0      NaN       NaN          NaN      45106.0
# 2024-12-27            129026.0      NaN   44522.0          NaN      86402.0
# 2024-12-28                 NaN  88325.0       NaN          NaN          NaN
# 2024-12-29                 NaN  43400.0   43418.0      84743.0      45178.0
# 2024-12-30                 NaN      NaN       NaN      81389.0          NaN
#
#
# Item Type  Glass Items Incense sticks Novelities Office Supplies
# Order Date
# 2015-01-01         NaN        42538.0        NaN         38954.0
# 2015-01-02     40911.0        40407.0        NaN             NaN
# 2015-01-03     77491.0       162472.0        NaN         45618.0
# 2015-01-04         NaN            NaN        NaN         39512.0
# 2015-01-05     83861.0       128704.0        NaN         43390.0
# ...                ...            ...        ...             ...
# 2024-12-26     46542.0        43064.0        NaN         44853.0
# 2024-12-27     42394.0       134294.0        NaN         38778.0
# 2024-12-28         NaN            NaN        NaN             NaN
# 2024-12-29     43957.0        44317.0        NaN             NaN
# 2024-12-30     43004.0        82297.0        NaN             NaN
#
# [3649 rows x 18 columns]

# %%
StockINandCommited[('Committed Stock', 'Chocolates/Biscuits')].plot.line()
StockINandCommited[('Stock On Hand', 'Chocolates/Biscuits')].plot.line()
# Out:
# <Axes: xlabel='Order Date'>

# %%
numerical_col = df.select_dtypes(include = ['int64','float64'])

# %%
df['Month'] = df['Order_Date'].dt.month
subset_df = df.select_dtypes(exclude = 'object')

data = subset_df.groupby(['Order Year','Month']).agg('mean')[['Item Availability rating' ,'Packaging Rating']]
data.reset_index(inplace=True)

fig = plt.figure(figsize=(11, 7))
ax = fig.add_subplot(111, projection='3d')


for i in range(1,len(data['Month'].unique())+1) :
    x = data[data['Month'] == i]
    ax.plot( x['Month'],x['Order Year'], x['Packaging Rating'])
#Set labels and title
ax.set_xlabel('Month')
ax.set_ylabel('Year')
ax.set_zlabel('Packaging Rating')
ax.set_title('3D Plot of Packaging Ratings')

# Add legend

ax.legend(data['Month'].unique())

# Show plot
plt.show()

# %% [markdown]
# ### Outlier

# %%
for col in numerical_col.columns.tolist():
    plt.boxplot(x=col,data=numerical_col)
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# ## Question 2

# %%
Demand_Df =  df[['Available for sale','Order Date']]
Demand_Df.head(5)
# Out:
#    Available for sale  Order Date
# 0               36244  2023-03-02
# 1               11282  2019-02-13
# 2               42122  2023-08-14
# 3               29919  2016-11-02
# 4               36171  2019-01-13

# %%
## Dropping Item Type Novelities   as it is only one record

# %%
Demand_Df.dtypes
# Out:
# Available for sale     int64
# Order Date            object
# dtype: object

# %%
# Converting Order Dat

print(Demand_Df.dtypes)

## Extracting Month Year from the Order Date column


Demand_Df['Month Year'] = Demand_Df['Order Date'].str.slice(start=0,stop=7)
Demand_Df.info()
# Out:
# Available for sale     int64
# Order Date            object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28179 entries, 0 to 28178
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Available for sale  28179 non-null  int64
#  1   Order Date          28179 non-null  object
#  2   Month Year          28179 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 660.6+ KB
# /var/folders/p2/0dct3c2n3031b7sgthqw_np00000gn/T/ipykernel_54313/620053041.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Demand_Df['Month Year'] = Demand_Df['Order Date'].str.slice(start=0,stop=7)

# %%
Demand_Df.head(5)
# Out:
#    Available for sale  Order Date Month Year
# 0               36244  2023-03-02    2023-03
# 1               11282  2019-02-13    2019-02
# 2               42122  2023-08-14    2023-08
# 3               29919  2016-11-02    2016-11
# 4               36171  2019-01-13    2019-01

# %%
# Feature Engineering to create a Demand Column from Available on Sales 
# mapping Available for Sale > 0 as 0 and Available for Sale < 0 as Postive Demand
Demand_Df['Demand'] = np.where(Demand_Df['Available for sale'] < 0  , -Demand_Df['Available for sale'] , 0)
Demand_Df['Demand'].describe()
# Out:
# /var/folders/p2/0dct3c2n3031b7sgthqw_np00000gn/T/ipykernel_54313/2917653064.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Demand_Df['Demand'] = np.where(Demand_Df['Available for sale'] < 0  , -Demand_Df['Available for sale'] , 0)
# count    28179.000000
# mean       597.256148
# std       3560.012183
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      53144.000000
# Name: Demand, dtype: float64

# %%
Demand_Df['Demand'].plot()
plt.show()

# %%
Final_Df = Demand_Df.groupby(['Month Year']).agg(sum)['Demand'].reset_index()
Final_Df.set_index('Month Year',inplace=True)
# Out:
# /var/folders/p2/0dct3c2n3031b7sgthqw_np00000gn/T/ipykernel_54313/3677445003.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   Final_Df = Demand_Df.groupby(['Month Year']).agg(sum)['Demand'].reset_index()

# %%
Final_Df['Demand'].plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

adf_test = adfuller(Final_Df['Demand'])
# Output the results
print('ADF Statistic: %f' % adf_test[0])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistic: -13.043747
# p-value: 0.000000

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(Final_Df['Demand'], lags=40)
plot_pacf(Final_Df['Demand'], lags=40)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
mask = Final_Df.index.str.contains(rf"^2024")

train_df = Final_Df[~mask]

test_df = Final_Df[mask]

# Fit the ARIMA model on the training dataset
model_train = ARIMA(train_df['Demand'], order=(5, 0, 2))
model_train_fit = model_train.fit()

# Forecast on the test dataset
test_forecast = model_train_fit.get_forecast(steps=len(test_df))
test_forecast_series = pd.Series(test_forecast.predicted_mean, index=test_df.index)

# Calculate the mean squared error
mse = mean_squared_error(test_df['Demand'], test_forecast_series)
rmse = mse**0.5

# Create a plot to compare the forecast with the actual test data
plt.figure(figsize=(20,10))
plt.plot(train_df['Demand'], label='Training Data')
plt.plot(test_df['Demand'], label='Actual Data', color='orange')
plt.plot(test_forecast_series, label='Forecasted Data', color='green')
plt.fill_between(test_df.index, 
                 test_forecast.conf_int().iloc[:, 0], 
                 test_forecast.conf_int().iloc[:, 1], 
                 color='k', alpha=.15)
plt.xticks(train_df.index[::10])
plt.title('ARIMA Model Evaluation')
plt.xlabel('Date')
plt.ylabel('Demand Month Year')
plt.legend()
plt.show()

print('RMSE:', rmse)
# Out:
# /Users/utkarshsingh/PycharmProjects/DSA/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/utkarshsingh/PycharmProjects/DSA/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/utkarshsingh/PycharmProjects/DSA/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# RMSE: 32590.408859056064

# %%
test_forecast_series
# Out:
# Month Year
# 2024-01    110566.616929
# 2024-02    139961.215472
# 2024-03    162441.257019
# 2024-04    118947.190620
# 2024-05    129352.955646
# 2024-06    160791.464864
# 2024-07    145528.129352
# 2024-08    125909.337053
# 2024-09    138286.229190
# 2024-10    150090.112299
# 2024-11    141535.151336
# 2024-12    134425.158901
# Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Question 4

# %%
df.isnull().sum()
# Out:
# ITEM ID                                    0
# LIST OF ITEMS                              0
# SKU                                       23
# \n          Warehouse Name\n               0
# Item Type                                  0
# Purchase Invoice Channel                   0
# Order Priority                             0
# Order Date                                 0
# Order ID                                   0
# Qty Ordered                                0
# Qty in                                     0
# Qty out                                    0
# Stock On Hand                              0
# Committed Stock                            0
# Available for sale                         0
# status                                     0
# unit                                       1
# Selling Price                              0
# Cost Price                                 0
# created_by                                 0
# Total money on hold                        0
# Item Availability rating                   7
# OFFLINE rating                             0
# Online booking Rating                      0
# Packaging Rating                           0
# Delivery Rating                         4238
# Order_Date                                 0
# Order Year                                 0
# Profit %                                 444
# Month                                      0
# dtype: int64

# %%
median_offline = df[df['Purchase Invoice Channel'] == 'Offline']['Delivery Rating'].median()
median_online = df[df['Purchase Invoice Channel'] == 'Online']['Delivery Rating'].median()
count = 0
df.loc[(df['Purchase Invoice Channel'] == 'Offline') & (df['Delivery Rating'].isnull()), 'Delivery Rating'] = median_offline
df.loc[(df['Purchase Invoice Channel'] == 'Online') & (df['Delivery Rating'].isnull()), 'Delivery Rating'] = median_online

# %%
df.isnull().sum()
# Out:
# ITEM ID                                   0
# LIST OF ITEMS                             0
# SKU                                      23
# \n          Warehouse Name\n              0
# Item Type                                 0
# Purchase Invoice Channel                  0
# Order Priority                            0
# Order Date                                0
# Order ID                                  0
# Qty Ordered                               0
# Qty in                                    0
# Qty out                                   0
# Stock On Hand                             0
# Committed Stock                           0
# Available for sale                        0
# status                                    0
# unit                                      1
# Selling Price                             0
# Cost Price                                0
# created_by                                0
# Total money on hold                       0
# Item Availability rating                  7
# OFFLINE rating                            0
# Online booking Rating                     0
# Packaging Rating                          0
# Delivery Rating                           0
# Order_Date                                0
# Order Year                                0
# Profit %                                444
# Month                                     0
# dtype: int64

# %%
# dropping the null values as it is very low 
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ITEM ID                                 0
# LIST OF ITEMS                           0
# SKU                                     0
# \n          Warehouse Name\n            0
# Item Type                               0
# Purchase Invoice Channel                0
# Order Priority                          0
# Order Date                              0
# Order ID                                0
# Qty Ordered                             0
# Qty in                                  0
# Qty out                                 0
# Stock On Hand                           0
# Committed Stock                         0
# Available for sale                      0
# status                                  0
# unit                                    0
# Selling Price                           0
# Cost Price                              0
# created_by                              0
# Total money on hold                     0
# Item Availability rating                0
# OFFLINE rating                          0
# Online booking Rating                   0
# Packaging Rating                        0
# Delivery Rating                         0
# Order_Date                              0
# Order Year                              0
# Profit %                                0
# Month                                   0
# dtype: int64

# %%
Q1 = np.percentile( df['Committed Stock'] , 25)
Q3 = np.percentile(df['Committed Stock'],75)

lowerBound =  Q1 - 1.5*(Q3-Q1)
upperBound =  Q3 + 1.5*(Q3-Q1)

outlier = df[(df['Committed Stock'] < lowerBound) | (df['Committed Stock'] > upperBound)]

# %%
len(outlier)
# Out:
# 2963

# %%
len(df)
# Out:
# 27704

# %%
df.select_dtypes(exclude= ['object']).corr()
# Out:
#                            ITEM ID       SKU  Order ID  Qty Ordered    Qty in  \
# ITEM ID                   1.000000 -0.014178 -0.004072    -0.001742 -0.001742
# SKU                      -0.014178  1.000000  0.003405     0.005791  0.005792
# Order ID                 -0.004072  0.003405  1.000000    -0.003635 -0.003635
# Qty Ordered              -0.001742  0.005791 -0.003635     1.000000  1.000000
# Qty in                   -0.001742  0.005792 -0.003635     1.000000  1.000000
# Qty out                  -0.001741  0.005792 -0.003635     1.000000  1.000000
# Stock On Hand            -0.001742  0.005792 -0.003636     1.000000  1.000000
# Committed Stock          -0.009621 -0.009559  0.008801    -0.006281 -0.006281
# Available for sale        0.009101  0.010476 -0.009322     0.196669  0.196669
# Selling Price            -0.127837 -0.001405  0.006194    -0.011783 -0.011783
# Cost Price                0.253024 -0.007898  0.008684    -0.011193 -0.011193
# Total money on hold       0.310879 -0.008026  0.007234     0.052401  0.052401
# Item Availability rating  0.193895 -0.003406 -0.003578     0.001077  0.001077
# OFFLINE rating            0.053464 -0.003730 -0.002746     0.004094  0.004094
# Online booking Rating     0.158339 -0.014154 -0.010635     0.003564  0.003564
# Packaging Rating          0.130116 -0.003073 -0.005591    -0.003522 -0.003522
# Delivery Rating           0.141708 -0.013123 -0.008423     0.001365  0.001365
# Order_Date               -0.009968  0.009626  0.008106    -0.000826 -0.000826
# Order Year               -0.009960  0.009027  0.008072    -0.000802 -0.000802
# Profit %                 -0.115109 -0.000134  0.003909     0.002169  0.002169
# Month                    -0.000123  0.006287  0.000103    -0.000386 -0.000386
#
#                            Qty out  Stock On Hand  Committed Stock  \
# ITEM ID                  -0.001741      -0.001742        -0.009621
# SKU                       0.005792       0.005792        -0.009559
# Order ID                 -0.003635      -0.003636         0.008801
# Qty Ordered               1.000000       1.000000        -0.006281
# Qty in                    1.000000       1.000000        -0.006281
# Qty out                   1.000000       1.000000        -0.006281
# Stock On Hand             1.000000       1.000000        -0.006281
# Committed Stock          -0.006281      -0.006281         1.000000
# Available for sale        0.196669       0.196669        -0.981686
# Selling Price            -0.011783      -0.011782         0.006703
# Cost Price               -0.011193      -0.011193        -0.004340
# Total money on hold       0.052401       0.052401        -0.005780
# Item Availability rating  0.001078       0.001078        -0.009062
# OFFLINE rating            0.004094       0.004095         0.004686
# Online booking Rating     0.003564       0.003565        -0.002480
# Packaging Rating         -0.003522      -0.003522        -0.016811
# Delivery Rating           0.001365       0.001365        -0.006735
# Order_Date               -0.000827      -0.000825        -0.004579
# Order Year               -0.000802      -0.000801        -0.004925
# Profit %                  0.002168       0.002169        -0.002205
# Month                    -0.000387      -0.000387         0.003090
#
#                           Available for sale  Selling Price  Cost Price  \
# ITEM ID                             0.009101      -0.127837    0.253024
# SKU                                 0.010476      -0.001405   -0.007898
# Order ID                           -0.009322       0.006194    0.008684
# Qty Ordered                         0.196669      -0.011783   -0.011193
# Qty in                              0.196669      -0.011783   -0.011193
# Qty out                             0.196669      -0.011783   -0.011193
# Stock On Hand                       0.196669      -0.011782   -0.011193
# Committed Stock                    -0.981686       0.006703   -0.004340
# Available for sale                  1.000000      -0.008817    0.002123
# Selling Price                      -0.008817       1.000000    0.710984
# Cost Price                          0.002123       0.710984    1.000000
# Total money on hold                 0.015650       0.659769    0.978210
# Item Availability rating            0.009090      -0.130801    0.044686
# OFFLINE rating                     -0.003815      -0.043159    0.012387
# Online booking Rating               0.003111      -0.133646    0.008590
# Packaging Rating                    0.015812      -0.099867    0.020089
# Delivery Rating                     0.006864      -0.091126    0.031116
# Order_Date                          0.004332      -0.002276   -0.003459
# Order Year                          0.004677      -0.001837   -0.003008
# Profit %                            0.002575       0.087632   -0.100231
# Month                              -0.003104      -0.003609   -0.003550
#
#                           Total money on hold  Item Availability rating  \
# ITEM ID                              0.310879                  0.193895
# SKU                                 -0.008026                 -0.003406
# Order ID                             0.007234                 -0.003578
# Qty Ordered                          0.052401                  0.001077
# Qty in                               0.052401                  0.001077
# Qty out                              0.052401                  0.001078
# Stock On Hand                        0.052401                  0.001078
# Committed Stock                     -0.005780                 -0.009062
# Available for sale                   0.015650                  0.009090
# Selling Price                        0.659769                 -0.130801
# Cost Price                           0.978210                  0.044686
# Total money on hold                  1.000000                  0.074475
# Item Availability rating             0.074475                  1.000000
# OFFLINE rating                       0.019405                  0.405011
# Online booking Rating                0.031897                  0.273299
# Packaging Rating                     0.040755                  0.143924
# Delivery Rating                      0.053016                  0.136508
# Order_Date                          -0.004387                 -0.003314
# Order Year                          -0.003994                 -0.004325
# Profit %                            -0.096237                 -0.047709
# Month                               -0.003115                  0.009902
#
#                           OFFLINE rating  Online booking Rating  \
# ITEM ID                         0.053464               0.158339
# SKU                            -0.003730              -0.014154
# Order ID                       -0.002746              -0.010635
# Qty Ordered                     0.004094               0.003564
# Qty in                          0.004094               0.003564
# Qty out                         0.004094               0.003564
# Stock On Hand                   0.004095               0.003565
# Committed Stock                 0.004686              -0.002480
# Available for sale             -0.003815               0.003111
# Selling Price                  -0.043159              -0.133646
# Cost Price                      0.012387               0.008590
# Total money on hold             0.019405               0.031897
# Item Availability rating        0.405011               0.273299
# OFFLINE rating                  1.000000               0.612774
# Online booking Rating           0.612774               1.000000
# Packaging Rating                0.094763               0.326160
# Delivery Rating                 0.076118               0.233597
# Order_Date                     -0.005402               0.000837
# Order Year                     -0.006179               0.000335
# Profit %                       -0.017114              -0.039191
# Month                           0.007461               0.004527
#
#                           Packaging Rating  Delivery Rating  Order_Date  \
# ITEM ID                           0.130116         0.141708   -0.009968
# SKU                              -0.003073        -0.013123    0.009626
# Order ID                         -0.005591        -0.008423    0.008106
# Qty Ordered                      -0.003522         0.001365   -0.000826
# Qty in                           -0.003522         0.001365   -0.000826
# Qty out                          -0.003522         0.001365   -0.000827
# Stock On Hand                    -0.003522         0.001365   -0.000825
# Committed Stock                  -0.016811        -0.006735   -0.004579
# Available for sale                0.015812         0.006864    0.004332
# Selling Price                    -0.099867        -0.091126   -0.002276
# Cost Price                        0.020089         0.031116   -0.003459
# Total money on hold               0.040755         0.053016   -0.004387
# Item Availability rating          0.143924         0.136508   -0.003314
# OFFLINE rating                    0.094763         0.076118   -0.005402
# Online booking Rating             0.326160         0.233597    0.000837
# Packaging Rating                  1.000000         0.298120    0.007151
# Delivery Rating                   0.298120         1.000000   -0.001959
# Order_Date                        0.007151        -0.001959    1.000000
# Order Year                        0.006582        -0.001632    0.994941
# Profit %                         -0.023478        -0.033334    0.006832
# Month                             0.006023        -0.003471    0.085331
#
#                           Order Year  Profit %     Month
# ITEM ID                    -0.009960 -0.115109 -0.000123
# SKU                         0.009027 -0.000134  0.006287
# Order ID                    0.008072  0.003909  0.000103
# Qty Ordered                -0.000802  0.002169 -0.000386
# Qty in                     -0.000802  0.002169 -0.000386
# Qty out                    -0.000802  0.002168 -0.000387
# Stock On Hand              -0.000801  0.002169 -0.000387
# Committed Stock            -0.004925 -0.002205  0.003090
# Available for sale          0.004677  0.002575 -0.003104
# Selling Price              -0.001837  0.087632 -0.003609
# Cost Price                 -0.003008 -0.100231 -0.003550
# Total money on hold        -0.003994 -0.096237 -0.003115
# Item Availability rating   -0.004325 -0.047709  0.009902
# OFFLINE rating             -0.006179 -0.017114  0.007461
# Online booking Rating       0.000335 -0.039191  0.004527
# Packaging Rating            0.006582 -0.023478  0.006023
# Delivery Rating            -0.001632 -0.033334 -0.003471
# Order_Date                  0.994941  0.006832  0.085331
# Order Year                  1.000000  0.006863 -0.014845
# Profit %                    0.006863  1.000000 -0.000901
# Month                      -0.014845 -0.000901  1.000000

# %%
#
correlation_matrix = df.select_dtypes(exclude= ['object']).corr().abs()

# Filter columns to remove based on correlation threshold
upper_triangle = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
columns_to_remove = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.8)]
print("list of Highly Correlated Columns")
print(columns_to_remove)
# Out:
# list of Highly Correlated Columns
# ['Qty in', 'Qty out', 'Stock On Hand', 'Available for sale', 'Total money on hold', 'Order Year']

# %%
df.rename(columns={'\n          Warehouse Name\n        ' : 'Warehouse_Name'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27704 entries, 0 to 28178
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ITEM ID                   27704 non-null  int64
#  1   LIST OF ITEMS             27704 non-null  object
#  2   SKU                       27704 non-null  float64
#  3   Warehouse_Name            27704 non-null  object
#  4   Item Type                 27704 non-null  object
#  5   Purchase Invoice Channel  27704 non-null  object
#  6   Order Priority            27704 non-null  object
#  7   Order Date                27704 non-null  object
#  8   Order ID                  27704 non-null  int64
#  9   Qty Ordered               27704 non-null  int64
#  10  Qty in                    27704 non-null  int64
#  11  Qty out                   27704 non-null  int64
#  12  Stock On Hand             27704 non-null  int64
#  13  Committed Stock           27704 non-null  int64
#  14  Available for sale        27704 non-null  int64
#  15  status                    27704 non-null  object
#  16  unit                      27704 non-null  object
#  17  Selling Price             27704 non-null  float64
#  18  Cost Price                27704 non-null  float64
#  19  created_by                27704 non-null  object
#  20  Total money on hold       27704 non-null  int64
#  21  Item Availability rating  27704 non-null  float64
#  22  OFFLINE rating            27704 non-null  int64
#  23  Online booking Rating     27704 non-null  int64
#  24  Packaging Rating          27704 non-null  int64
#  25  Delivery Rating           27704 non-null  float64
#  26  Order_Date                27704 non-null  datetime64[ns]
#  27  Order Year                27704 non-null  int32
#  28  Profit %                  27704 non-null  float64
#  29  Month                     27704 non-null  int32
# dtypes: datetime64[ns](1), float64(6), int32(2), int64(12), object(9)
# memory usage: 6.3+ MB

# %% [markdown]
# ## Handling Categorical Features

# %%
df['Purchase Invoice Channel'].value_counts()
# Out:
# Purchase Invoice Channel
# Offline    13999
# Online     13705
# Name: count, dtype: int64

# %%
df['Purchase Invoice Channel'].replace({'Offline':1,'Online':0},inplace=True)

# %%
df['status'].value_counts()
# Out:
# status
# active      27684
# inactive       20
# Name: count, dtype: int64

# %%
df['status'].replace({'active':1,'inactive':0},inplace=True)

# %%
df['unit'].value_counts()
# Out:
# unit
# Pcs                21189
# PCS                 2315
# pcs                 2223
# BOX                 1206
# box                  651
# CASE                  31
# PACK                  31
# DISPLAY               26
# JAR                   10
# Box                    6
# BAG                    3
# PSC                    3
# PC                     3
# PCS4                   2
# BO                     1
# 80X                    1
# PCS716165291053        1
# P S                    1
# PCS7.50                1
# Name: count, dtype: int64

# %%
 df.drop('unit',axis = 1 , inplace=True)

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# LOW              7028
# HIGH             6940
# MOST PRIORITY    6895
# MEDIUM           6839
# LOW/MEDIUM          2
# Name: count, dtype: int64

# %%
# First merging the LOW/Medium Order Priority as Medium as it is only 2 records
df.replace({'LOW/MEDIUM' :'MEDIUM'},inplace=True)
# Now replacing this Order Priority based on order as it Ordinal Column
df.replace({'MOST PRIORITY':3 , 'HIGH':2 ,'MEDIUM' : 1 , 'LOW':0},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27704 entries, 0 to 28178
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ITEM ID                   27704 non-null  int64
#  1   LIST OF ITEMS             27704 non-null  object
#  2   SKU                       27704 non-null  float64
#  3   Warehouse_Name            27704 non-null  object
#  4   Item Type                 27704 non-null  object
#  5   Purchase Invoice Channel  27704 non-null  int64
#  6   Order Priority            27704 non-null  int64
#  7   Order Date                27704 non-null  object
#  8   Order ID                  27704 non-null  int64
#  9   Qty Ordered               27704 non-null  int64
#  10  Qty in                    27704 non-null  int64
#  11  Qty out                   27704 non-null  int64
#  12  Stock On Hand             27704 non-null  int64
#  13  Committed Stock           27704 non-null  int64
#  14  Available for sale        27704 non-null  int64
#  15  status                    27704 non-null  int64
#  16  Selling Price             27704 non-null  float64
#  17  Cost Price                27704 non-null  float64
#  18  created_by                27704 non-null  object
#  19  Total money on hold       27704 non-null  int64
#  20  Item Availability rating  27704 non-null  float64
#  21  OFFLINE rating            27704 non-null  int64
#  22  Online booking Rating     27704 non-null  int64
#  23  Packaging Rating          27704 non-null  int64
#  24  Delivery Rating           27704 non-null  float64
#  25  Order_Date                27704 non-null  datetime64[ns]
#  26  Order Year                27704 non-null  int32
#  27  Profit %                  27704 non-null  float64
#  28  Month                     27704 non-null  int32
# dtypes: datetime64[ns](1), float64(6), int32(2), int64(15), object(5)
# memory usage: 6.1+ MB

# %%
# Creating a dummies variable for Warehouse_Name , Item_Type as it Nominal Col

df = pd.get_dummies(df,columns = ['Warehouse_Name','Item Type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27704 entries, 0 to 28178
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ITEM ID                                  27704 non-null  int64
#  1   LIST OF ITEMS                            27704 non-null  object
#  2   SKU                                      27704 non-null  float64
#  3   Purchase Invoice Channel                 27704 non-null  int64
#  4   Order Priority                           27704 non-null  int64
#  5   Order Date                               27704 non-null  object
#  6   Order ID                                 27704 non-null  int64
#  7   Qty Ordered                              27704 non-null  int64
#  8   Qty in                                   27704 non-null  int64
#  9   Qty out                                  27704 non-null  int64
#  10  Stock On Hand                            27704 non-null  int64
#  11  Committed Stock                          27704 non-null  int64
#  12  Available for sale                       27704 non-null  int64
#  13  status                                   27704 non-null  int64
#  14  Selling Price                            27704 non-null  float64
#  15  Cost Price                               27704 non-null  float64
#  16  created_by                               27704 non-null  object
#  17  Total money on hold                      27704 non-null  int64
#  18  Item Availability rating                 27704 non-null  float64
#  19  OFFLINE rating                           27704 non-null  int64
#  20  Online booking Rating                    27704 non-null  int64
#  21  Packaging Rating                         27704 non-null  int64
#  22  Delivery Rating                          27704 non-null  float64
#  23  Order_Date                               27704 non-null  datetime64[ns]
#  24  Order Year                               27704 non-null  int32
#  25  Profit %                                 27704 non-null  float64
#  26  Month                                    27704 non-null  int32
#  27  Warehouse_Name_TEXAS DISTRIBUTION        27704 non-null  bool
#  28  Warehouse_Name_TX Boyz WHOLESALE-khaled  27704 non-null  bool
#  29  Warehouse_Name_TX Boyz Wholesale         27704 non-null  bool
#  30  Warehouse_Name_Tx Boyz Wholesale A#103   27704 non-null  bool
#  31  Item Type_Chocolates/Biscuits            27704 non-null  bool
#  32  Item Type_Clothes                        27704 non-null  bool
#  33  Item Type_Cosmetics                      27704 non-null  bool
#  34  Item Type_Exotic Chips                   27704 non-null  bool
#  35  Item Type_ExoticDrinks                   27704 non-null  bool
#  36  Item Type_Glass Items                    27704 non-null  bool
#  37  Item Type_Incense sticks                 27704 non-null  bool
#  38  Item Type_Novelities                     27704 non-null  bool
#  39  Item Type_Office Supplies                27704 non-null  bool
# dtypes: bool(13), datetime64[ns](1), float64(6), int32(2), int64(15), object(3)
# memory usage: 6.1+ MB

# %%
df.columns.tolist()
# Out:
# ['ITEM ID',
#  'LIST OF ITEMS',
#  'SKU',
#  'Purchase Invoice Channel',
#  'Order Priority',
#  'Order Date',
#  'Order ID',
#  'Qty Ordered',
#  'Qty in',
#  'Qty out',
#  'Stock On Hand',
#  'Committed Stock',
#  'Available for sale',
#  'status',
#  'Selling Price',
#  'Cost Price',
#  'created_by',
#  'Total money on hold',
#  'Item Availability rating',
#  'OFFLINE rating',
#  'Online booking Rating',
#  'Packaging Rating',
#  'Delivery Rating',
#  'Order_Date',
#  'Order Year',
#  'Profit %',
#  'Month',
#  'Warehouse_Name_TEXAS DISTRIBUTION',
#  'Warehouse_Name_TX Boyz WHOLESALE-khaled',
#  'Warehouse_Name_TX Boyz Wholesale',
#  'Warehouse_Name_Tx Boyz Wholesale A#103',
#  'Item Type_Chocolates/Biscuits',
#  'Item Type_Clothes',
#  'Item Type_Cosmetics',
#  'Item Type_Exotic Chips',
#  'Item Type_ExoticDrinks',
#  'Item Type_Glass Items',
#  'Item Type_Incense sticks',
#  'Item Type_Novelities',
#  'Item Type_Office Supplies']

# %%
df['Customer Satisfication']  = (df[['Item Availability rating',
 'OFFLINE rating',
 'Online booking Rating',
 'Packaging Rating',
 'Delivery Rating']].sum(axis=1) > 15).astype(int)

df['Customer Satisfication'].value_counts()
# Out:
# Customer Satisfication
# 1    17639
# 0    10065
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Customer Satisfication > 15

# %%
# Splitting the data into 0.7 train , 0.3 test data

Indepedent_feature = [
 'Purchase Invoice Channel',
 'Order Priority',
 'Qty Ordered',
 'Qty in',
 'Qty out',
 'Stock On Hand',
 'Committed Stock',
 'Available for sale',
 'status',
 'Selling Price',
 'Cost Price',
 'Total money on hold',
 'Customer Satisfication',
 'Warehouse_Name_TEXAS DISTRIBUTION',
 'Warehouse_Name_TX Boyz WHOLESALE-khaled',
 'Warehouse_Name_TX Boyz Wholesale',
 'Warehouse_Name_Tx Boyz Wholesale A#103',
 'Item Type_Chocolates/Biscuits',
 'Item Type_Clothes',
 'Item Type_Cosmetics',
 'Item Type_Exotic Chips',
 'Item Type_ExoticDrinks',
 'Item Type_Glass Items',
 'Item Type_Incense sticks',
 'Item Type_Novelities',
 'Item Type_Office Supplies' ]
final_df = df[Indepedent_feature]
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27704 entries, 0 to 28178
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Purchase Invoice Channel                 27704 non-null  int64
#  1   Order Priority                           27704 non-null  int64
#  2   Qty Ordered                              27704 non-null  int64
#  3   Qty in                                   27704 non-null  int64
#  4   Qty out                                  27704 non-null  int64
#  5   Stock On Hand                            27704 non-null  int64
#  6   Committed Stock                          27704 non-null  int64
#  7   Available for sale                       27704 non-null  int64
#  8   status                                   27704 non-null  int64
#  9   Selling Price                            27704 non-null  float64
#  10  Cost Price                               27704 non-null  float64
#  11  Total money on hold                      27704 non-null  int64
#  12  Customer Satisfication                   27704 non-null  int64
#  13  Warehouse_Name_TEXAS DISTRIBUTION        27704 non-null  bool
#  14  Warehouse_Name_TX Boyz WHOLESALE-khaled  27704 non-null  bool
#  15  Warehouse_Name_TX Boyz Wholesale         27704 non-null  bool
#  16  Warehouse_Name_Tx Boyz Wholesale A#103   27704 non-null  bool
#  17  Item Type_Chocolates/Biscuits            27704 non-null  bool
#  18  Item Type_Clothes                        27704 non-null  bool
#  19  Item Type_Cosmetics                      27704 non-null  bool
#  20  Item Type_Exotic Chips                   27704 non-null  bool
#  21  Item Type_ExoticDrinks                   27704 non-null  bool
#  22  Item Type_Glass Items                    27704 non-null  bool
#  23  Item Type_Incense sticks                 27704 non-null  bool
#  24  Item Type_Novelities                     27704 non-null  bool
#  25  Item Type_Office Supplies                27704 non-null  bool
# dtypes: bool(13), float64(2), int64(11)
# memory usage: 3.3 MB

# %%
Y = final_df['Customer Satisfication']
X = final_df.drop('Customer Satisfication', axis=1)
X_train , X_test , Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=342)
print("Train Size : {}".format(len(X_train)))
print("Test Size : {}".format(len(X_test)))
# Out:
# Train Size : 19392
# Test Size : 8312

# %%
pipelines ={
    'lr' : make_pipeline(StandardScaler(),LogisticRegression(penalty='l2',random_state =123)),
    'rf'  : make_pipeline(StandardScaler(),RandomForestClassifier(random_state=123)),
    'dt' : make_pipeline(StandardScaler(),DecisionTreeClassifier(random_state=123))
  }

# %%
lr_hyperparamter = {
'logisticregression__C':[0.001,0.005,0.01,0.5]
}

# %%
pipelines['rf'].get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('randomforestclassifier', RandomForestClassifier(random_state=123))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'randomforestclassifier': RandomForestClassifier(random_state=123),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'randomforestclassifier__bootstrap': True,
#  'randomforestclassifier__ccp_alpha': 0.0,
#  'randomforestclassifier__class_weight': None,
#  'randomforestclassifier__criterion': 'gini',
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__max_features': 'sqrt',
#  'randomforestclassifier__max_leaf_nodes': None,
#  'randomforestclassifier__max_samples': None,
#  'randomforestclassifier__min_impurity_decrease': 0.0,
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'randomforestclassifier__n_estimators': 100,
#  'randomforestclassifier__n_jobs': None,
#  'randomforestclassifier__oob_score': False,
#  'randomforestclassifier__random_state': 123,
#  'randomforestclassifier__verbose': 0,
#  'randomforestclassifier__warm_start': False}

# %%
rf_hyperparameter = {
    'randomforestclassifier__max_depth' : [ 1,2,5,10,12],
    'randomforestclassifier__n_estimators' : [100,200,400,500],
    'randomforestclassifier__max_features' : ['sqrt','log2']}

# %%
pipelines['dt'].get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('decisiontreeclassifier', DecisionTreeClassifier(random_state=123))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'decisiontreeclassifier': DecisionTreeClassifier(random_state=123),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'decisiontreeclassifier__ccp_alpha': 0.0,
#  'decisiontreeclassifier__class_weight': None,
#  'decisiontreeclassifier__criterion': 'gini',
#  'decisiontreeclassifier__max_depth': None,
#  'decisiontreeclassifier__max_features': None,
#  'decisiontreeclassifier__max_leaf_nodes': None,
#  'decisiontreeclassifier__min_impurity_decrease': 0.0,
#  'decisiontreeclassifier__min_samples_leaf': 1,
#  'decisiontreeclassifier__min_samples_split': 2,
#  'decisiontreeclassifier__min_weight_fraction_leaf': 0.0,
#  'decisiontreeclassifier__random_state': 123,
#  'decisiontreeclassifier__splitter': 'best'}

# %%
dt_hyperparameter = {
    'decisiontreeclassifier__max_depth': [1,5,10], 
    'decisiontreeclassifier__min_samples_split' :[0.1,0.2,0.5,0.05],
   'decisiontreeclassifier__max_features': [ 'sqrt', 'log2'],
    'decisiontreeclassifier__criterion': ['gini','entropy'],
    'decisiontreeclassifier__min_samples_leaf' :[0.1,0.2,0.5,0.05]
    
}

# %%
Hyperparamter = {
    'lr' : lr_hyperparamter ,
    'rf' : rf_hyperparameter,
    'dt' :dt_hyperparameter
}

# %%
# Fit and Tune models with Cross-Validation

from sklearn.model_selection import GridSearchCV
 
fitted_models={}

for name , pipeline in pipelines.items() :
    
    model = GridSearchCV(pipeline ,Hyperparamter[name],cv=5,n_jobs=-1)
    
    model.fit(X_train,Y_train)
    
    fitted_models[name] = model 
    
    print(name, 'has been fitted')
# Out:
# lr has been fitted
# rf has been fitted
# dt has been fitted

# %%
fitted_models['rf']
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(random_state=123))]),
#              n_jobs=-1,
#              param_grid={'randomforestclassifier__max_depth': [1, 2, 5, 10, 12],
#                          'randomforestclassifier__max_features': ['sqrt',
#                                                                   'log2'],
#                          'randomforestclassifier__n_estimators': [100, 200, 400,
#                                                                   500]})

# %%
from sklearn.metrics import accuracy_score
for name ,model in fitted_models.items():
    pred=model.predict(X_train)
    print("NAME :",name)
    print('----------------')
    
    
    print("Accuracy SCORE:",accuracy_score(Y_train,pred))
    print('----------------')
# Out:
# NAME : lr
# ----------------
# Accuracy SCORE: 0.6599628712871287
# ----------------
# NAME : rf
# ----------------
# Accuracy SCORE: 0.6970915841584159
# ----------------
# NAME : dt
# ----------------
# Accuracy SCORE: 0.661355198019802
# ----------------

# %%
from sklearn.metrics import accuracy_score



for name ,model in fitted_models.items():
    pred=model.predict(X_test)
    print("NAME :",name)
    print('----------------')
    
    
    print("Accuracy SCORE:",accuracy_score(Y_test,pred))
    print('----------------')
# Out:
# NAME : lr
# ----------------
# Accuracy SCORE: 0.6659047160731473
# ----------------
# NAME : rf
# ----------------
# Accuracy SCORE: 0.6779355149181906
# ----------------
# NAME : dt
# ----------------
# Accuracy SCORE: 0.6592877767083735
# ----------------

# %%
# Compute confusion matrix
from sklearn.metrics import confusion_matrix

labels = [1, 0]

accuracy_list = []
specificity_list= []
sensitivity_list = []
for name, model in fitted_models.items() : 
    y_pred = model.predict(X_test)
    cm = confusion_matrix(Y_test, y_pred ,labels=[1,0])
    TP = cm[0, 0]
    FN = cm[0, 1]
    FP = cm[1, 0]
    TN = cm[1, 1]
    accuracy_list.append(accuracy_score(Y_test,y_pred))
    specificity_list.append(TN/(FP+TN))
    sensitivity_list.append(TP/(FN+TP))
                         
# Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sb.heatmap(cm, annot=True, cmap='Blues', fmt='d', 
            xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# Create bar plot
model_names = ['logistic Regression','Random Forsest Classifier','Decision Tree Classifier']
plt.figure(figsize=(10, 6))

# Plotting accuracy
plt.bar([x - 0.2 for x in range(len(fitted_models))],accuracy_list, width=0.2, label='Accuracy')
# Plotting specificity
plt.bar([x for x in range(len(fitted_models))], specificity_list, width=0.2, label='Specificity')
# Plotting sensitivity
plt.bar([x + 0.2 for x in range(len(fitted_models))], sensitivity_list, width=0.2, label='Sensitivity')

plt.xlabel('Models')
plt.ylabel('Metrics')
plt.title('Performance Metrics of Models')
plt.xticks(range(len(model_names)),model_names  )
plt.legend()
plt.show()
